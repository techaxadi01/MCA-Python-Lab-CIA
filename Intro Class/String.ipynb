# %%
chr(97)
# Out:
# 'a'

# %%
ord("A")
# Out:
# 65

# %% [markdown]
# String Slicing

# %%
x = "Aditya"
sp = " "
y = "Kumar"

# %%
print(x+sp+y)
print((x+sp)*5)
print(y[:2])
print(x[0:10])
print(x[0:10:2])
print(x[0:3])
print(y[-5:-3])
# Out:
# Aditya Kumar
# Aditya Aditya Aditya Aditya Aditya
# Ku
# Aditya
# Aiy
# Adi
# Ku
